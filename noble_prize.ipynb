# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

nobel = pd.read_csv("archive.csv")

# half_count = len(nobel) / 2
# nobel = nobel.dropna(thresh=half_count,axis=1) # Drop any column with more than 50% missing values

nobel
# Out:
#      Year    Category                                              Prize  \
# 0    1901   Chemistry                  The Nobel Prize in Chemistry 1901
# 1    1901  Literature                 The Nobel Prize in Literature 1901
# 2    1901    Medicine     The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                         The Nobel Peace Prize 1901
# 4    1901       Peace                         The Nobel Peace Prize 1901
# 5    1901     Physics                    The Nobel Prize in Physics 1901
# 6    1902   Chemistry                  The Nobel Prize in Chemistry 1902
# 7    1902  Literature                 The Nobel Prize in Literature 1902
# 8    1902    Medicine     The Nobel Prize in Physiology or Medicine 1902
# 9    1902       Peace                         The Nobel Peace Prize 1902
# 10   1902       Peace                         The Nobel Peace Prize 1902
# 11   1902     Physics                    The Nobel Prize in Physics 1902
# ...

# %%
nobel.count()
# Out:
# Year                    969
# Category                969
# Prize                   969
# Motivation              881
# Prize Share             969
# Laureate ID             969
# Laureate Type           969
# Full Name               969
# Birth Date              940
# Birth City              941
# Birth Country           943
# Sex                     943
# Organization Name       722
# Organization City       716
# Organization Country    716
# Death Date              617
# Death City              599
# Death Country           605
# dtype: int64

# %%
org_nobel = nobel[nobel["Laureate Type"] == "Organization"]
in_nobel = nobel[nobel["Laureate Type"] == "Individual"]



g = org_nobel.loc[(org_nobel['Birth Date'].notnull())]
# g= w['Laureate Type'].map({'female': 1, 'male': 0})

s =  g.replace("Organization", "Individual")



new_indu =  in_nobel.append(s)

# new_indu['Birth Date'] = pd.to_datetime(new_indu['Birth Date'], format='%Y-%m-%d')

new_indu
# Out:
#      Year    Category                                              Prize  \
# 0    1901   Chemistry                  The Nobel Prize in Chemistry 1901
# 1    1901  Literature                 The Nobel Prize in Literature 1901
# 2    1901    Medicine     The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                         The Nobel Peace Prize 1901
# 4    1901       Peace                         The Nobel Peace Prize 1901
# 5    1901     Physics                    The Nobel Prize in Physics 1901
# 6    1902   Chemistry                  The Nobel Prize in Chemistry 1902
# 7    1902  Literature                 The Nobel Prize in Literature 1902
# 8    1902    Medicine     The Nobel Prize in Physiology or Medicine 1902
# 9    1902       Peace                         The Nobel Peace Prize 1902
# 10   1902       Peace                         The Nobel Peace Prize 1902
# 11   1902     Physics                    The Nobel Prize in Physics 1902
# ...

# %%
new_org = org_nobel.loc[(org_nobel["Laureate Type"]== "Organization") & (org_nobel['Birth Date'].isna())] 

new_org = new_org.drop(['Birth Date','Birth City','Birth Country','Sex','Death Date','Death Country','Death City','Organization City','Organization Name','Organization Country'], axis=1)
new_org
# Out:
#      Year Category                       Prize  \
# 24   1904    Peace  The Nobel Peace Prize 1904
# 61   1910    Peace  The Nobel Peace Prize 1910
# 90   1917    Peace  The Nobel Peace Prize 1917
# 206  1938    Peace  The Nobel Peace Prize 1938
# 222  1944    Peace  The Nobel Peace Prize 1944
# 244  1947    Peace  The Nobel Peace Prize 1947
# 245  1947    Peace  The Nobel Peace Prize 1947
# 295  1954    Peace  The Nobel Peace Prize 1954
# 365  1963    Peace  The Nobel Peace Prize 1963
# 366  1963    Peace  The Nobel Peace Prize 1963
# 383  1965    Peace  The Nobel Peace Prize 1965
# 416  1969    Peace  The Nobel Peace Prize 1969
# 498  1977    Peace  The Nobel Peace Prize 1977
# 543  1981    Peace  The Nobel Peace Prize 1981
# 578  1985    Peace  The Nobel Peace Prize 1985
# 610  1988    Peace  The Nobel Peace Prize 1988
# 682  1995    Peace  The Nobel Peace Prize 1995
# 705  1997    Peace  The Nobel Peace Prize 1997
# 728  1999    Peace  The Nobel Peace Prize 1999
# ...

# %%
#in the individual dataset USA is the dominante in winning the nobel prizes
from matplotlib.pyplot import hist


u = new_indu['Birth Country'].value_counts().rename_axis('Countries').reset_index(name='Number_of_Nobel_Prizes')

u = u [0:10]
u
# Out:
#                   Countries  Number_of_Nobel_Prizes
# 0  United States of America                     276
# 1            United Kingdom                      88
# 2                   Germany                      70
# 3                    France                      53
# 4                    Sweden                      30
# 5                     Japan                      29
# 6                    Russia                      20
# 7               Netherlands                      19
# 8                     Italy                      18
# 9                    Canada                      18

# %%
sns.set()
# and setting the size of all plots.
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [11, 7]

# Plotting USA born winners 
ax = sns.lineplot(data=u, x="Countries", y="Number_of_Nobel_Prizes")
# ax.set_xticklabels(u['Countries'], rotation='vertical', fontsize=10)
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='large'  
)
plt.show()


# # Adding %-formatting to the y-axis
# from matplotlib.ticker import PercentFormatter
# ax.yaxis.set_major_formatter(PercentFormatter())

# %%
# Calculating the proportion of USA born winners per decade
new_indu['usa_born_winner'] = new_indu["Birth Country"] == "United States of America"
new_indu['decade'] = (np.floor(new_indu["Year"] / 10) * 10).astype(int)
prop_usa_winners = new_indu.groupby("decade", as_index=False)["usa_born_winner"].mean()

prop_usa_winners
# Out:
#     decade  usa_born_winner
# 0     1900         0.017544
# 1     1910         0.078947
# 2     1920         0.074074
# 3     1930         0.245902
# 4     1940         0.309524
# 5     1950         0.282051
# 6     1960         0.276316
# 7     1970         0.311321
# 8     1980         0.322917
# 9     1990         0.403846
# 10    2000         0.426471
# 11    2010         0.347368

# %%
plt.rcParams['figure.figsize'] = [11, 7]

ax = sns.lineplot(x=prop_usa_winners["decade"], y=prop_usa_winners["usa_born_winner"])

# Adding %-formatting to the y-axis
from matplotlib.ticker import PercentFormatter
ax.yaxis.set_major_formatter(PercentFormatter())

# %%
o =  new_org['Full Name'].value_counts().rename_axis('Organization_Name').reset_index(name='Number_of_Nobel_Prizes')
o
# Out:
#                                     Organization_Name  Number_of_Nobel_Prizes
# 0   Comité international de la Croix Rouge (Intern...                       3
# 1   Office of the United Nations High Commissioner...                       2
# 2                           National Dialogue Quartet                       1
# 3           International Atomic Energy Agency (IAEA)                       1
# 4    Intergovernmental Panel on Climate Change (IPCC)                       1
# 5                                 European Union (EU)                       1
# 6   Bureau international permanent de la Paix (Per...                       1
# 7   Office international Nansen pour les Réfugiés ...                       1
# 8    Pugwash Conferences on Science and World Affairs                       1
# 9   Institut de droit international (Institute of ...                       1
# 10                 United Nations Peacekeeping Forces                       1
# ...

# %%
plt.figure(figsize=(10,5))
plt.rcParams['figure.figsize'] = [11, 7]

# Plotting USA born winners 
ax = sns.countplot(data=new_org, x="Full Name")
# ax.set_xticklabels(u['Countries'], rotation='vertical', fontsize=10)
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='large'  
)
plt.show()

# %%
# Calculating the proportion of female laureates per decade
new_indu['female_winner'] = new_indu["Sex"] == "Female"
prop_female_winners = new_indu.groupby(["decade", "Category"], as_index=False)["female_winner"].mean()

# Plotting USA born winners with % winners on the y-axis
ax = sns.lineplot(x="decade", y="female_winner", hue="Category", data=prop_female_winners)

# %%
# Picking out the first woman to win a Nobel Prize
df1 = new_indu[new_indu["Sex"] == "Female"]
df1.nsmallest(1, "Year")
# Out:
#     Year Category                            Prize  \
# 19  1903  Physics  The Nobel Prize in Physics 1903
#
#                                            Motivation Prize Share  \
# 19  "in recognition of the extraordinary services ...         1/4
#
#     Laureate ID Laureate Type                    Full Name  Birth Date  \
# 19            6    Individual  Marie Curie, née Sklodowska  1867-11-07
#
#    Birth City  ...     Sex Organization Name Organization City  \
# 19     Warsaw  ...  Female               NaN               NaN
#
#    Organization Country  Death Date  Death City Death Country female_winner  \
# 19                  NaN  1934-07-04  Sallanches        France          True
#
#     usa_born_winner  decade
# 19            False    1900
#
# [1 rows x 21 columns]

# %%
# Selecting the laureates that have received 2 or more prizes.
new_indu.groupby("Full Name").filter(lambda x: len(x) >= 2)
# Out:
#      Year   Category                                              Prize  \
# 19   1903    Physics                    The Nobel Prize in Physics 1903
# 46   1908   Medicine     The Nobel Prize in Physiology or Medicine 1908
# 47   1908   Medicine     The Nobel Prize in Physiology or Medicine 1908
# 63   1911  Chemistry                  The Nobel Prize in Chemistry 1911
# 157  1931  Chemistry                  The Nobel Prize in Chemistry 1931
# 158  1931  Chemistry                  The Nobel Prize in Chemistry 1931
# 159  1931  Chemistry                  The Nobel Prize in Chemistry 1931
# 160  1931  Chemistry                  The Nobel Prize in Chemistry 1931
# 179  1934   Medicine     The Nobel Prize in Physiology or Medicine 1934
# 180  1934   Medicine     The Nobel Prize in Physiology or Medicine 1934
# 187  1936  Chemistry                  The Nobel Prize in Chemistry 1936
# 188  1936  Chemistry                  The Nobel Prize in Chemistry 1936
# ...

# %%
# removing the wrong Birth Date Values which where like Y-00-00 , into NaN
new_indu.at[342, 'Birth Date'] = np.NaN
new_indu.at[748, 'Birth Date'] = np.NaN
test  = new_indu[new_indu['Full Name'].str.contains("Albert John Lutuli")==True]

test
# Out:
#      Year Category                       Prize Motivation Prize Share  \
# 342  1960    Peace  The Nobel Peace Prize 1960        NaN         1/1
#
#      Laureate ID Laureate Type           Full Name Birth Date Birth City  ...  \
# 342          519    Individual  Albert John Lutuli        NaN   Bulawayo  ...
#
#       Sex Organization Name Organization City Organization Country  \
# 342  Male               NaN               NaN                  NaN
#
#      Death Date Death City Death Country female_winner  usa_born_winner  \
# 342  1967-07-21    Stanger  South Africa         False            False
#
#      decade
# 342    1960
#
# [1 rows x 21 columns]

# %%
# Converting birth_date from String to datetime
new_indu['Birth Date'] = pd.to_datetime(new_indu["Birth Date"],format='%Y-%m-%d')

# Calculating the age of Nobel Prize winners
new_indu['Age'] = new_indu["Year"] - new_indu["Birth Date"].dt.year

# Plotting the age of Nobel Prize winners
sns.lmplot(x="Year", y="Age", data=new_indu, lowess=True, aspect=2, line_kws={"color" : "black"})

# %%
# Same plot as above, but separate plots for each type of Nobel Prize
sns.lmplot(x="Year", y="Age", data=new_indu, row="Category", lowess=True, aspect=2, line_kws={"color" : "black"})

# %%
# The oldest winner of a Nobel Prize as of 2016
display(new_indu.nlargest(1, "Age"))

# The youngest winner of a Nobel Prize as of 2016
new_indu.nsmallest(1, "Age")
# Out:
#      Year   Category                                              Prize  \
# 825  2007  Economics  The Sveriges Riksbank Prize in Economic Scienc...
#
#                                             Motivation Prize Share  \
# 825  "for having laid the foundations of mechanism ...         1/3
#
#      Laureate ID Laureate Type       Full Name Birth Date Birth City  ...  \
# 825          820    Individual  Leonid Hurwicz 1917-08-21     Moscow  ...
#
#            Organization Name Organization City      Organization Country  \
# 825  University of Minnesota   Minneapolis, MN  United States of America
#
#      Death Date       Death City             Death Country female_winner  \
# 825  2008-06-24  Minneapolis, MN  United States of America         False
#
#     usa_born_winner  decade   Age
# 825           False    2000  90.0
#
# [1 rows x 22 columns]
#      Year Category                       Prize  \
# 940  2014    Peace  The Nobel Peace Prize 2014
#
# ...

# %%
# The name of the youngest winner of the Nobel Prize as of 2016
youngest_winner = 'Malala'
